# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>importing libraries numpy, pandas, and matplotlib and seaborn</h1>

# %%
train_data = pd.read_csv("train_titanic.csv")

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_data.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot('Survived',data=train_data)
plt.show()
# Out:
# /Users/avigyarana/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train_data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
sns.countplot('Sex',hue='Survived',data=train_data)
plt.show()
# Out:
# /Users/avigyarana/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot('Pclass',hue='Survived',data=train_data)
plt.title("Pclass: survived vs dead")
plt.show()
# Out:
# /Users/avigyarana/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab([train_data.Sex, train_data.Survived],train_data.Pclass,margins=True).style.background_gradient(cmap="summer_r")
# Out:
# <style type="text/css">
# #T_d28d1_row0_col0, #T_d28d1_row0_col1, #T_d28d1_row0_col3, #T_d28d1_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d28d1_row0_col2, #T_d28d1_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_d28d1_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_d28d1_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_d28d1_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_d28d1_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_d28d1_row2_col1, #T_d28d1_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_d28d1_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_d28d1_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_d28d1_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_d28d1_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex',data=train_data, kind='point')
plt.show()

# %%
print("oldest person survived was ", train_data[train_data["Survived"]==1]['Age'].max())
print("youngest person survived was ", train_data[train_data["Survived"]==1]['Age'].min())
print("average person survived was ", train_data[train_data["Survived"]==1]['Age'].mean())
# Out:
# oldest person survived was  80.0
# youngest person survived was  0.42
# average person survived was  28.343689655172415

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x='Pclass',y='Age',hue='Survived',data=train_data, split=True, ax=ax[0])
ax[0].set_title("pclass and age vs survived")
ax[0].set_yticks(range(0,110,10))
sns.violinplot(x='Sex',y='Age',hue='Survived',data=train_data, split=True, ax=ax[1])
ax[1].set_title("Sex and age vs survived")
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
train_data['Initial']=0
for i in train_data:
    train_data['Initial'] = train_data.Name.str.extract('([A-Za-z]+)\.')

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(train_data.Initial,train_data.Sex).T.style.background_gradient(cmap="summer_r")
# Out:
# <style type="text/css">
# #T_d4f25_row0_col0, #T_d4f25_row0_col1, #T_d4f25_row0_col3, #T_d4f25_row0_col4, #T_d4f25_row0_col5, #T_d4f25_row0_col7, #T_d4f25_row0_col8, #T_d4f25_row0_col12, #T_d4f25_row0_col15, #T_d4f25_row0_col16, #T_d4f25_row1_col2, #T_d4f25_row1_col6, #T_d4f25_row1_col9, #T_d4f25_row1_col10, #T_d4f25_row1_col11, #T_d4f25_row1_col13, #T_d4f25_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d4f25_row0_col2, #T_d4f25_row0_col6, #T_d4f25_row0_col9, #T_d4f25_row0_col10, #T_d4f25_row0_col11, #T_d4f25_row0_col13, #T_d4f25_row0_col14, #T_d4f25_row1_col0, #T_d4f25_row1_col1, #T_d4f25_row1_col3, #T_d4f25_row1_col4, #T_d4f25_row1_col5, #T_d4f25_row1_col7, #T_d4f25_row1_col8, #T_d4f25_row1_col12, #T_d4f25_row1_col15, #T_d4f25_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d4f25">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
train_data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
train_data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
train_data.loc[(train_data.Age.isnull())& (train_data.Initial =='Mr'),'Age']=33
train_data.loc[(train_data.Age.isnull())& (train_data.Initial =='Mrs'),'Age']=36
train_data.loc[(train_data.Age.isnull())& (train_data.Initial =='Master'),'Age']=5
train_data.loc[(train_data.Age.isnull())& (train_data.Initial =='Miss'),'Age']=22
train_data.loc[(train_data.Age.isnull())& (train_data.Initial =='Other'),'Age']=46

# %%
train_data.Age.isnull().any()
# Out:
# False

# %%
f, ax= plt.subplots(1,2,figsize=(20,20))
train_data[train_data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20, edgecolor='black',color='red')
ax[0].set_title('Survived =0')
x1 = list(range(0,85,5))
ax[0].set_xticks(x1)
train_data[train_data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor = 'black',color='green')
x2 = list(range(0,85,5))
ax[1].set_xticks(x2)
ax[1].set_title('Survived =1')
plt.show()

# %%
plt.figure(figsize=(10,100))
sns.catplot('Pclass','Survived',col='Initial',data=train_data,kind='point')
plt.show()
# Out:
# /Users/avigyarana/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#feature: sibling spouse (sibsp)

pd.crosstab([train_data.SibSp],train_data.Survived).style.background_gradient('summer_r')
# Out:
# <style type="text/css">
# #T_28ee5_row0_col0, #T_28ee5_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_28ee5_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_28ee5_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_28ee5_row2_col0, #T_28ee5_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_28ee5_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_28ee5_row3_col0, #T_28ee5_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_28ee5_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_28ee5_row5_col0, #T_28ee5_row5_col1, #T_28ee5_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_28ee5_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_28ee5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
# ...

# %%
f,ax = plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=train_data, ax=ax[0])
ax[0].set_title('Sibsp vs survived in barplot')
sns.factorplot('SibSp','Survived',data=train_data,ax=ax[1])
ax[1].set_title('Sibsp vs Survived in factorplot')
plt.show()
# Out:
# /Users/avigyarana/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/avigyarana/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %%
pd.crosstab(train_data.SibSp,train_data.Pclass).style.background_gradient('summer_r')
# Out:
# <style type="text/css">
# #T_ff335_row0_col0, #T_ff335_row0_col1, #T_ff335_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_ff335_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_ff335_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_ff335_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_ff335_row2_col0, #T_ff335_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_ff335_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_ff335_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_ff335_row3_col0, #T_ff335_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_ff335_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_ff335_row4_col0, #T_ff335_row4_col1, #T_ff335_row5_col0, #T_ff335_row5_col1, #T_ff335_row5_col2, #T_ff335_row6_col0, #T_ff335_row6_col1 {
#   background-color: #ffff66;
# ...
